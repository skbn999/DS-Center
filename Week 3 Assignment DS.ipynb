# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the file¶

# %%
data1=pd.read_excel('iris.xls')

# %% [markdown]
# # Displaying the columns in the dataset

# %%
data1.head(10)
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa
# 5  5.4  3.9  1.7  0.4    Iris-setosa
# 6  4.6  3.4  1.4  0.3    Iris-setosa
# 7  5.0  3.4  1.5  0.2    Iris-setosa
# 8  4.4  2.9  1.4  0.2    Iris-setosa
# 9  4.9  3.1  1.5  0.1    Iris-setosa

# %% [markdown]
# # Finding the mean of each column

# %%
data1.mean(axis=0,skipna=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for Null values

# %%
data1.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Visualizations of the dataset

# %% [markdown]
# Countplot

# %%
sns.countplot(data1['Classification'])
plt.show()
# Out:
# C:\Users\stbch\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x=data1['SL'],y=data1['SW'],hue=data1['Classification'])
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
sns.scatterplot(x=data1['PL'],y=data1['PW'],hue=data1['Classification'])
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %% [markdown]
# Lineplot

# %%
sns.lineplot(x=data1['PL'],y=data1['PW'],hue=data1['Classification'])
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %%
sns.lineplot(x=data1['SL'],y=data1['SW'],hue=data1['Classification'])
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>
